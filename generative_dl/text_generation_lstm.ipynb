# %% [markdown]
# <a href="https://colab.research.google.com/github/ernestomancebo/DeepLearningInPractice/blob/main/generative_dl/text_generation_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Text Generation with LSTM
#
# In this notebook we will feed into a LSTM network a corpus form Nietzche, later we'll provide a snippet that will kick the LSTM to generate what should be the next sequences, feed that output back in for several iterations and see what's the result.
#
# Getting the Corpus.

# %%
import numpy as np
from keras import utils

path = utils.get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()

print(f'Corpust length: {len(text)}')
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpust length: 600893

# %% [markdown]
# Now we vectorize the sequence of characters (corpus).
#
# The `sentences` and `next_chars` will act as a `n gram`.

# %%
maxlen = 60
step = 3

sentences = []
next_chars = []

# From the first element until the i-est elemnt - maxlen.
# maxlen is reserved for the next_chars
for i in range(0, len(text) - maxlen, step):
  sentences.append(text[i : i + maxlen])
  next_chars.append(text[i + maxlen])

print(f'Number of sequences: {len(sentences)}')

chars = sorted(list(set(text)))
print(f'Unique chars count: {len(chars)}')

# This is a char-index-map
char_indices = dict(
    (c, chars.index(c)) for c in chars
)
# Out:
# Number of sequences: 200278
# Unique chars count: 57

# %% [markdown]
# ##Vectorization
#
# Here we vectorize the sequences, so the LSTM network can digest it.

# %%
# The sequences acts as samples. The Vocabulary size
# are the possibles elements to appear (target).
# maxlen is the dimention (padded) of each sequence 
sequences_count = len(sentences)
vocabulary_size = len(chars)

x = np.zeros((sequences_count, maxlen, vocabulary_size), dtype=np.bool)
y = np.zeros((sequences_count, vocabulary_size), dtype=np.bool)

for i, sentence in enumerate(sentences):
  for j, c in enumerate(sentence):
    # This builds a one-hot-like tensor with dimenssion:
    # instances x sequences x vocabulary, which
    # vocaublary is the  encoded value.
    x[i, j, char_indices[c]] = 1
  y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# ##Building the LSTM model

# %%
from keras import layers
from keras.models import Sequential
from keras.optimizers import RMSprop

model = Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, vocabulary_size)))
model.add(layers.Dense(vocabulary_size, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.01))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               95232
# _________________________________________________________________
# dense (Dense)                (None, 57)                7353
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###Sampling Function
#
# The next function will do some adjustment in the prediction probabilities by the model and throw a randomnized potential output.

# %%
def sample(predictions, temperature=1.0):
  preds = np.asarray(predictions).astype('float64')
  preds = np.log(preds) / temperature

  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)

  return np.argmax(probas)

# %% [markdown]
# ###Text Generation Loop
#
# This loop trains (epoch) and generates text. The text is generated in a range of distinct temperature at each epoch. This allow us to see when the model starts to converge and also the incidence of the temperature in the model.

# %%
import random
import sys

# This is to make prints cute.
padder = '-' * 5

for epoch in range(1, 60):
  print(f'\n\nEpoch: {epoch}')

  model.fit(x, y, batch_size=128, epochs=1)
  # Pick a random index
  start_index = random.randint(0, len(text) - maxlen - 1)
  generated_text = text[start_index : start_index + maxlen]
  print(f'\n{padder} Generating with seed: {generated_text} {padder}\n')

  for temperature in [0.2, 0.5, 1., 1.2]:
    print(f'\n{padder} Temperature: {temperature} {padder}\n')
    sys.stdout.write(generated_text)

    for i in range(400):
      sampled = np.zeros((1, maxlen, vocabulary_size))
      # one-hot-encode the seed (generated_text) as an input tensor
      for t, char in enumerate(generated_text):
        sampled[0, t, char_indices[char]] = 1
      
      preds = model.predict(sampled, verbose=0)[0]
      # Get the most likely next character according to the prediction 
      # and the current temperature
      next_index = sample(preds, temperature)
      next_char = chars[next_index]

      # Here we slide the seed (generated_text) window (sequence)
      # for the next iteration
      generated_text += next_char
      generated_text = generated_text[1:]

      sys.stdout.write(next_char)
# Out:
# Epoch: 1
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3522
#
# ----- Generating with seed: was different with felix mendelssohn, that halcyon
# master, w -----
#
#
# ----- Temperature: 0.2 -----
#
# was different with felix mendelssohn, that halcyon
# master, which is a spiritual presenter to the stronger of the best of the consequently in the subject and consequently so the same them to the greater to the stronger of the souls, and the subject and perhaps the superstition of the stronger of the subject to the subject and the subjective and souls, and the privile to the subject and consequently and souls, and there is to be subject and more in the most
# ----- Temperature: 0.5 -----
#
#  and souls, and there is to be subject and more in the most suffering and misunderstanding and at the person for his insight and than has a sure, in the christian to the fals of man who has perhaps be perhaps to be subjective to distingunating, and also have no longer all the subject of the personal spirituality of placition and being posit problem of the privile and man all the state and now he not it is not be no present in his state of the experience an
# ----- Temperature: 1.0 -----
#
# ot it is not be no present in his state of the experience and feeling could say protog-that cholking conrower.
# the philosophers of much, no perhaps bothing implement at venceded his nettray aspertablen and the superstition
# of age is dischaturary that is "be come larulity and the fefulness, the tim, in as
# to suld phrisoment, to be believes, be modes of everything ethicm in the dermining distinctivey uponrable at the "christian abouty has everly are ourselve
# ----- Temperature: 1.2 -----
#
# y uponrable at the "christian abouty has everly are ourselves
# delusions consequentlyly nature.
# but he prunces which
# is
# assumerity became long-like
# nocesions hir law no genderarie,
# when ont word as mores
# sort
# in to-that out, to tas up forhing for, at least his in
# unjustiumal certainly, it is
# "form for houd much has learnes an invigaters. he is its cirilikes, those woild of are prenederarier sawnidileshers. very ordering case, good maeth
# circelac are hithert
#
# Epoch: 2
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3478
#
# ----- Generating with seed: re, inaccessible and incomprehensible to
# us: it would become -----
#
#
# ----- Temperature: 0.2 -----
#
# re, inaccessible and incomprehensible to
# us: it would become an interpretation of the still same and the stronger the basism of the sense of the stronger and the sense of the world and the sense of the conception of the precisely and interpretation of the still soul the still also the still good the subtle sense of the strength of the same time the sense of the same time the still one has a comparison of the same time the soul and also the same time the sa
# ----- Temperature: 0.5 -----
#
# ison of the same time the soul and also the same time the same above the subject man has in the conceited into the secarary in the case of the existence of the sensities of the subteral in the strengthers and discostion is also once in all experience of sympathy of a man and it an interinates of the delicate and with the pressives and intersally and morality and become in the present sense and science, the instinct which one must distrued into the grace th
# ----- Temperature: 1.0 -----
#
# ence, the instinct which one must distrued into the grace that the matilihtly no able of
# the
# dischysicses. this perting the result, and the first europe
# within the horient.
#
#
# 14ve com really indeed the such an thic-desires them--he you highe" has gald. what
# deptect by hadd, per always
# i spowend for himly
# disinterction-will, for the entinidity.
#
# 1e of human the
# severical midder
# impossible which, look as a
# net perspeace, from sympathy--and much to the great
# ----- Temperature: 1.2 -----
#
# ok as a
# net perspeace, from sympathy--and much to the great strosgovers by morality--hereavound theke dipsugness and who siver may lefort or doe, corrunce of ordinin, as woman of the falouledd inty anyimhiiscaral evolur reternsted ver cast-aging knownisx, that is by from the
# by the among theor num, in this
# met,
# "worth happed to
# bound scrumine, by which nevertheled, hitherto physisired attain the lately, haticn
# be just
# who happens" of a pasted to asks which
#
# Epoch: 3
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3409
#
# ----- Generating with seed: earned, and perhaps philosophers also, if
# appearances do not -----
#
#
# ----- Temperature: 0.2 -----
#
# earned, and perhaps philosophers also, if
# appearances do not an interestine of the brought and some heing and the sense of the consequently in the sense of the ways and actions of the still be substial and souls to the strength of the still be sublimes and the free spiritual in the strength of the still as a surplfish the strong and action of the sense of the still in the still be surplus of the sense of the strength of the still be strong and an experienc
# ----- Temperature: 0.5 -----
#
# ense of the strength of the still be strong and an experiences, and the
# eventuall-friends, and the pastical of the still in the same as a deniul the evil of a things of experience to the sense of the fact of the sinking and also something for the origin, the fundamentally wearity. the astatis("way and the soul and man is the fully thinking of the sublimes and as the sentiment of which the same result in the historical spiritual an interestine and comes as
# ----- Temperature: 1.0 -----
#
# ult in the historical spiritual an interestine and comes as the taste: nowastan but a very europe. the in that a good
# origin of secarning, it also deivent outgen of grame assumplies go the germaniemy chaaced so i our other a
# consequently be ruled.
# disactimilitics, a
# consequent perpaty is do table blisbwon bithery and in o  hardshable "bourier to knowledge reverity
# which must to "breakes. the den within more multuc of small
# evilentwerness in merely--the sub
# ----- Temperature: 1.2 -----
#
# ithin more multuc of small
# evilentwerness in merely--the subsfers is moreover with arevers and
# be no
# lew apopposibieable adaptitude emostrice to an earch eventui
# like
# classicn lack author, immenses of the glonnity for histority. then," easodager to religios. if morexhe purity of more
# fe. qui had it, surfecive every feels also non ifletabitional
# deniely itself--cale abuoted, ehoperation of depusts in emitentered. the sert tk
# through havening opestite outsio
#
# Epoch: 4
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3369
#
# ----- Generating with seed: sophy reduced to
# a "theory of knowledge," no more in fact th -----
#
#
# ----- Temperature: 0.2 -----
#
# sophy reduced to
# a "theory of knowledge," no more in fact the father and contradiction of the same emotion of the sentiments of the stronger and profound the sense of the fact the sense of the probleman and the reality of the father and the contradiction of the stronger of the contradiction of the latter the man in the superficial and contrary the same the supposing the contrary and the present of the world and stronger, and the stronger, and the stranges
# ----- Temperature: 0.5 -----
#
#  the world and stronger, and the stronger, and the stranges and controlings, and attempt, it is earth, and the most should as an intencue, the instincts, the works. and and only the most create which are conscience.
#
#
# 133
#
# =antities, the heart so modern with the contralileal to antakes and fact as it is also the contrary and concealment and ages and intellectual and characters of the truth
# of the stronger, the greatest mankind of the original and evil, it
# ----- Temperature: 1.0 -----
#
# stronger, the greatest mankind of the original and evil, it does no longer its great controlory geninements--fashience in the last events another when they only sies an
# already and
# men has speathered
# becomes would cunnersled to be
# originality o.other, with concealmential and "godse. there are, or formey is
# creates moralited the corpore, and
# sbittdy is say,
# inlivent however, nert of that troptistic pretracher
# exagequent hitherto indivicious, throughelther,
#
# ----- Temperature: 1.2 -----
#
#  pretracher
# exagequent hitherto indivicious, throughelther,
# and unfeerse misroves, that were
# is a the slyen, under pet an injuleres bsid, there once been sage, and curiosity. unjust
# debedientjment, irrecemble of misfethety, the view, the mindce--a thing
# contend.
#
# fared of dust know undighistic advincaue the
# roman artiplical most
# a new questively and bavity,--is also with the mairy
# imple, or case for it waok appeoth grow daoligicgia
# allise it, the crontrous
#
# Epoch: 5
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3318
#
# ----- Generating with seed: eligions.
#
#
# 124
#
# =sinlessness of men.=--if one have understo -----
#
#
# ----- Temperature: 0.2 -----
#
# eligions.
#
#
# 124
#
# =sinlessness of men.=--if one have understood," and the father, as the spirit is a soul and consequence that the stronger the most strictly fair and such a success of the father and the gradually the greek, the stronger and the stronger and more of the present the senses and such a delight and most desires and concerning and the senses of the stronger and the latter and fair of the senses and such an ideal of the superfiring the senses and
# ----- Temperature: 0.5 -----
#
# e senses and such an ideal of the superfiring the senses and refinement to be we love the really in the world of the degradrate the most problem of philosophing the mad perfect that the german almost and the future his live to spirit of the fact that which we even sentiment in the father, the very precisely in every profound and come of propers the made the philosophers and are more store self-great perfect to be denking the assument all personal confusion
# ----- Temperature: 1.0 -----
#
# at perfect to be denking the assument all personal confusion and ethicativitud reface as a man artiste. to moral old are psychological fair who hardings"--there is discernableness, such man to cithstrese, his way
# and influences,
# bucture for every consider nedigness to the supposes
# and ; "i pergiblal unserval to point of consideral that conscience, andsed
# entire within us nothing man minhtress is you arsistarility in the thrards the computing
# in "in who ele
# ----- Temperature: 1.2 -----
#
# ou arsistarility in the thrards the computing
# in "in who elevered for a prowinging, and not been hether unfulshion, (men
# man more custom. , lain strging psycham in looe, that man
# visitd instilal generasions aper rone show have beetly a
# ponsear dinn
# charact habnes amait atde"bvior. and opcinsd nuper little stilar kurming distriad to deading glorification the laid happine! understands
# wh? who was recaute. kneutahorure who has know for yous abere adnation, bo
#
# Epoch: 6
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3267
#
# ----- Generating with seed: right to demand that
# others, whose daily lives are not empty -----
#
#
# ----- Temperature: 0.2 -----
#
# right to demand that
# others, whose daily lives are not empty of the same time and conscience of the stronger of the sense of the standard of the sense of the states and states and conscience and stronger of the states and spiritual and called the precisely and conscience of the states and the stronger of the same time and conscience of the strength of the sense of the states and all the stronger of the sense of the states and will to the sense of the stand
# ----- Temperature: 0.5 -----
#
# f the sense of the states and will to the sense of the standard of the precisely even has only something
# good enough than have a conscience and all the conceptions and controluness of the purpose of the conceptions, as an interpretation which is not personal delight to self-contrioring the man, and and endure will be science of the same time of the religious the testament, and not all the more delicate to states that is also pains the structuaricians of co
# ----- Temperature: 1.0 -----
#
# icate to states that is also pains the structuaricians of compquiately, in its intellect to a serious-great life is long, hate so european matriquence. this would not soul-suddenly best: in whom wooch-narrope and create he will
# to irrifate blond
# to phtrenging, formsting these ormance as not wad it is time, in made oberages that when himher all addiest dugth and scienceians an indisented the impulse of finflf-and elevoter still; however, have resence to the
# ----- Temperature: 1.2 -----
#
# e of finflf-and elevoter still; however, have resence to the senses to what a man," all sure-cis not on
# the sage that rortal usmosancest; he mediocmentiration against esil as tole no
# the , dige re" that ye dyla, thus is allowomen
# and thelessw) of
# him. timement. the every leasy, truedtiantlates. is feuls
# plant pile of
# itagnd"--being by this thing from gherea. augoiquelnes to a may prestumes it, a
# provinices, we"
# qu
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# e rares, meany, his roclekd and our
# seloogi
#
# Epoch: 7
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3231
#
# ----- Generating with seed: xperienced only in the
# suffering of another, as in the case  -----
#
#
# ----- Temperature: 0.2 -----
#
# xperienced only in the
# suffering of another, as in the case of the spirit of the same states of the strong and the same and more and so the stronger to the same and power and so the best of the strong and spirit in the intellectual and sure, the superficial in the stronger of the spirit to be at the same to be a man and conscious sense of the states of the strong and more and so the best of the sense of the strong and such and so not of the states of the s
# ----- Temperature: 0.5 -----
#
# nse of the strong and such and so not of the states of the sense of the latter of the sense of the free spirit is a songful enough and is be states of the best of a colled be perceive of the so purpose of the well with it in his spirit and self-desired how place of the bood in the states of a man in the worst which of person of himself of a common conscious men to says. a schools to be any hard conceive
# and in the same worthed in the latter and society in
# ----- Temperature: 1.0 -----
#
# nceive
# and in the same worthed in the latter and society in jey overthing, spillest the other their same more,
# but danger to
# life and virtues in
# philosophers mend, but they have been bemouned to
# stell lowe) for intolant must be a do as they are conception, in will too hamm it        arality of worther? without and almost power has. .onpictic to our denier. as there is great synleties--they or, has a power degaties it be rule in into commanded i mand"; not,
# ----- Temperature: 1.2 -----
#
#  a power degaties it be rule in into commanded i mand"; not, for naes, withered the ideas desebly much and mitter eno,
# the
# feeling ent. if they he under a man, again, youthers; as found of human a
# emo house in
# aughes evil, and fligents of negerentike made fictled"" to--has
# very stating each
# fliefty to life. nold, -he was of this predeth is narror in an initiates belage at leadence all the alt of himself, as therefore, in the
# bestivitees is sertedd
# let of l
#
# Epoch: 8
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3212
#
# ----- Generating with seed: ok at
# those poor historians, the sybels and treitschkes, and -----
#
#
# ----- Temperature: 0.2 -----
#
# ok at
# those poor historians, the sybels and treitschkes, and thereby it is not the sense of the sense of the strength, the soul, the presentimes the same time and delicate the constraintic and men of the same things, and it is the world of the presentimity the sense of the superior to the moral conscience of the sense of the sense of the sense of his superior to the sense of the sense of the same time and such an impossible, and thereby so nothing the real
# ----- Temperature: 0.5 -----
#
# time and such an impossible, and thereby so nothing the realition of a profound the
# one of this learn himself and such a morality to such a delicate precisely from succes of this god be deep all of the presentimitation to constraint souls, which has been so suffering upon the superior to the precisely but thereby the love and the fines seriously, as striving and conscience, and as a man were manifold to be have forting of the greatest privite to which the
# ----- Temperature: 1.0 -----
#
# old to be have forting of the greatest privite to which the entity the esiumble a
# counte
# brairs of seek with odden beephate, skepered--grejection to
# hands with he has achie strong, orgination, should
# have there
# is, there is by order the strongorous-; also the feeling of
#  rate
# alfost kind of this awwore should does not us, one thing throe-powhes greatest, but have a may wisting such sympathy which such man,
# as to an
# imprimity. all as , tooy of
# myselfring an
# ----- Temperature: 1.2 -----
#
# such man,
# as to an
# imprimity. all as , tooy of
# myselfring andiethor aadly, and last about occurding to
# benelawly and the martiuiatie ibreades
# than strengthing, if a superiousnazed himself theircly how so religists, enie repearly,
# and it, in his own faith
# oremetw, we, all teach thereof.--pshatic have hitherto ourselves of si batter and go greeking mischomeing,
# taking ex metablorical
# morally, who meade an
# succed. iveriev,
# an immetrration thee? ut: as in efor
#
# Epoch: 9
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3160
#
# ----- Generating with seed: ecisely in respect to
# men of "modern ideas" that we have con -----
#
#
# ----- Temperature: 0.2 -----
#
# ecisely in respect to
# men of "modern ideas" that we have conscience of the most spirit of the sense of the same and the stronger in the strength of the sense of the sense of the spirit of the fact that the sense of the stronger and soul and an a great the stronger and desires of the same the ordinary and antified and the stronger the sense of the means of the same and present the sense of the sense of the spirit of the same and propered to the sense of the
# ----- Temperature: 0.5 -----
#
# e of the spirit of the same and propered to the sense of the most present that the stone with the far and a the world of such and the destruction of the tester of the german much of the act a meanter, and the nature, a germany the masters and the belief in such a means of the same and conscienced the series of the love to art nowadays, as the busting of the will to the alterneting the soul, and will can to the contrine to conscience of the strength to fren
# ----- Temperature: 1.0 -----
#
# ll can to the contrine to conscience of the strength to french and branscess
# and inatebter are the possible to mean that sonfegles of philosophariann
# . higher,
#
# if the soul of one mus of onlyt retrodiagion
# from the entradity"--with which a young and by vidernary frellous. one wrutable have bengerman us eperat world of the storthor, these meadually, inhuman kidling the concerning christianity fless, toly securation? upon
# to the tradity. woman
# ta"ke
# virtues
# ----- Temperature: 1.2 -----
#
# , toly securation? upon
# to the tradity. woman
# ta"ke
# virtues a perspecial affisming.=--look, of bue voluntarily, ecrlation.
#
# 137.
#
#
# he unwe can well education adrmity,
# with world knows, bn.=--he 'bindibing-minger
# by
# ceer of err princially.--renied it, now only does amthanher, hild rightf. modicr and "succeief?ly and gafishing,
# namely ambigions met nobled.omed
# morales",--she really, love as is at have cictunge by vind, through lits the first of the comput le
#
# Epoch: 10
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3128
#
# ----- Generating with seed: ays--nothing!
#
# nice, spring, 1886.
#
#
#
#
# of the first and last -----
#
#
# ----- Temperature: 0.2 -----
#
# ays--nothing!
#
# nice, spring, 1886.
#
#
#
#
# of the first and last and something and such a contempt of the scientific and also the command--and the strength of the controlity of the strong to the same thing that a contemplate the soul of the spirit and something something in the same and something and desire to the sense of the strong and contempt of the strong of the strength of the contempt of the strong of the fact of the strength of the spirit of the same t
# ----- Temperature: 0.5 -----
#
# rong of the fact of the strength of the spirit of the same thought of the generated as all perhaps be "contemplate the schopenhauer the famile, the moral of the fathers of the new the philosophers to exception of things and newje perhaps the more against who have been for the perhaps there are not the problem of things between all serves and between such a discipline of self-contement of the experience and depends of the has at all experience of the last w
# ----- Temperature: 1.0 -----
#
# ience and depends of the has at all experience of the last wiche advertablious enfur as he healthiness, they have idumnorisimity and badness reason to the reason-that
# the knows as music hembel
# and spirit, and
# to the newrtind" timat it socies and changes.r? it is possess for domand findreds of only and alsomes of his much were mann
# states! it thing it to "unlipance the also volith than
# is necessity of called defens, whether or theplyficious surmouni,
# some o
# ----- Temperature: 1.2 -----
#
#  of called defens, whether or theplyficious surmouni,
# some of every. the "new to nature.
#
#
# 03omwise
# swilling of rigener,ed.
# dences form of the
# reason
# make ket on we helpwil is repeative sfigurd, for folly of posticisming in my
# who so "mother otselficp of which decognizance a getanic vamility of a desirlness liking midtle, what--is tliction and dependent than
# condes,
# light
# indifaitification, whom, not be averebolow of smick of her
# good,
# alevanth, more will
#
# Epoch: 11
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3099
#
# ----- Generating with seed: laws without having thereby endangered the "eternal salvatio -----
#
#
# ----- Temperature: 0.2 -----
#
# laws without having thereby endangered the "eternal salvation of the same the strengths and self-contact the most spiritual and souls and something so much the strength, which we have a spirits of the strength, and who has in the sense of the same consists the spiritually and strength of the sense of the same the sacrifice of the same the most same manifests and the desire the sense of the senses and the strengths of the same the same the sense of the sens
# ----- Temperature: 0.5 -----
#
# and the strengths of the same the same the sense of the sense of conception of men that desires of every new play, but the spirits and the sacrifice, the whole of the second thd mades of distertance, the same all the men and certain the
# works of the way of the worst and solent the mastery, but the best of this father of the respect to its whole and
# that it be miderian souls who will the words
# of
# super-tocrity of the hard interpreted, and harditure of the s
# ----- Temperature: 1.0 -----
#
# uper-tocrity of the hard interpreted, and harditure of the strength oneu
# some will to will to difficulty, or stapices upon
# that noble. the ever for the mass
# ecrior. not only acmostic in
# europe, it vesperative
# instincts which bold to whom the stalt; the sensation of lightens, a closed
# wbitable. a ancients, in cruel such a duscated
# perhaps
# domined; the
# elejudated mutually thus how speits and controlier must, lantlotinge
# in the religion many the problem of re
# ----- Temperature: 1.2 -----
#
# ier must, lantlotinge
# in the religion many the problem of relaging individuations,
# towards us-made and set will bitse, is everwhole, those may
# becomesno, one chim-itse
# orici
# totge transbcaume--firal
# from art for h
# : is seeks of
# the relight, envorked
# manfer, theouls? he cunner, we easily
# criotice
# always he we desiringe about
# all out have,
# would pretitylogicalst miverandful dorised modernce dhart-.w. live class, for a svepexing comparably coohous only here
#
# Epoch: 12
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3049
#
# ----- Generating with seed: ldren--they call that "education"; no mother
# doubts at the b -----
#
#
# ----- Temperature: 0.2 -----
#
# ldren--they call that "education"; no mother
# doubts at the borng, the subjucts, and the presence of the same time that the proper things of the fact of the strength of the concernism of the same time and the same things that the senses and the subjucts, and the subjucts--and that the more and brain and the strong of the science and something that the same time and all the same time and the strong of the same time and the contrary and all the same time and
# ----- Temperature: 0.5 -----
#
# of the same time and the contrary and all the same time and commere the belief to the world as the fester. he reals. it is all the senses and depression, but therefore, and that no position of the fact of morality. that who has a conscience, in the strength and fellow our own that which the spirit and at that therefore, or man is it portenifical from a production of the same will be will always the german that he does not at the readility that the communit
# ----- Temperature: 1.0 -----
#
# e german that he does not at the readility that the communities or thus believes, from them yester (even proper and sistantimy".
#
# 183. "the
# most concerning bebterbvatics--understood will have instincts," and he is
# commonry of course, whether takes and now has wecre
# that they are represent bestrosple every darjust, he wanter clisement and denione almost more could do dungquevolous as, to calses, and it believy parghy becaure it is that
# speak simples as all
# ----- Temperature: 1.2 -----
#
# d it believy parghy becaure it is that
# speak simples as all chase, they doings learned tober formult ecear elevol. it is abity whatever indminity with,"
# of caws no let a
# chearths and will tradition,
# after artains much aduqualituous an extrity,--misunver rank hiinver, the histerad godly from emo mule switm regards to dlare of society; but ill it would gryt
# in
# thusish, although--hy thus harmjura
# man grosks of girtus.besently
# delightsely brven", class of plea
#
# Epoch: 13
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3011
#
# ----- Generating with seed: tain it is tantamount to an attack of fever, that passes awa -----
#
#
# ----- Temperature: 0.2 -----
#
# tain it is tantamount to an attack of fever, that passes away to the same than all the same and protection of the sentent of the sense of the same to the same things to the same things the superficially not to the same to the sense of the fact of the same to self-conscience of the superficially the communical the same and superficial consequence of the same things to the strength the superficially the one of the same things and the destruction of the conte
# ----- Temperature: 0.5 -----
#
#  the one of the same things and the destruction of the contempt of the intellectually the destiny of the master--that only the most things and who consequence of a problem of really and bruis, the point of the constitutes according to the opinion of the expression of the suddenly the same than such a partial in the sense of the delight is not have to should be not be like one must be some things and will to orgine and manner--when the consequence of the sa
# ----- Temperature: 1.0 -----
#
# nd will to orgine and manner--when the consequence of the same "most fully fear, gestrable toals, speciespted of the storks from
# my
# closely yeash, whether it is a
# of russ, as rechulized and emotional
# in des to the one had afune, achment belong to man
# tergat better acvect! the men and with thewpose should very debeded look if if i have him look of the domain to honour them endulled
# of allhought to could general house, the case always the summon that the d
# ----- Temperature: 1.2 -----
#
# o could general house, the case always the summon that the distandamentramity can varidy of man, what
# unjust undreteshing," has
# laugh to found and
# a rapines
# bad can  sharcvamies"s, there last teachorard intolach itself it, growing parodoxed no, and
# street judgment, where dancegorist,
# niralize
# frairs to the charkps, at life the sacrity angils,
# as too-call with this proso,
# but the nustry holfing delight
# good sreat, fill hyput upon syolorid discool of great d
#
# Epoch: 14
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2997
#
# ----- Generating with seed: ely the same fate of europe was able to speak, which
# knew ho -----
#
#
# ----- Temperature: 0.2 -----
#
# ely the same fate of europe was able to speak, which
# knew how to the same proper of the same and contempt of the superiorst and all the seconger the most strength of the seconger and souls, it is a human the strong and souls, and the seconger of the second, and the senses of the same and man is a comparison of the seconger the strength of the same and souls, it is a comprised and considerable senses and man is the senses of the superiors the most same supe
# ----- Temperature: 0.5 -----
#
# es and man is the senses of the superiors the most same superiory. if the
# activity of the world as the preciate conception of the promise in the best thinger, and also the severier are science experience is according to the superiories of the second the superiorst the superiorst and experience, as if they find the desirved as a desirns and
# strong of the stretjate of most stranges a period of the tendency, it is seems to cause of the fact one called the sup
# ----- Temperature: 1.0 -----
#
# endency, it is seems to cause of the fact one called the sup, imprainess of the case of the future
# innerered and taken soliement neflectively, according to man, all the
# best fact the emoty
# of grand to
# a collence becoming the langless, in such godces at southard. grantisms, is here
# approximated hand makes to strange desirning
# and conferst of things in truth-sunsuble to reptictiness, a weakenwning said, still had to qualitually, it is theolosh. but it is a p
# ----- Temperature: 1.2 -----
#
# aid, still had to qualitually, it is theolosh. but it is a philosopher hand presspest will be have schollisce with,
# have been affination of decides okes
# natures: colleness, who says in a thuss. the but ong himself an a
# resisted--conscious.
#
#
# 11chup cleaulices, mepracd and raty, lettw, their waking
# holking justists to herieable unwapilishs of hosties is
# heret
# reyswfer of the findered christian difference, one iman worker mady of apility
# aftershing a phi-dod
#
# Epoch: 15
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2990
#
# ----- Generating with seed:  style of the
# world of heraclitus, plato, empedocles, and wh -----
#
#
# ----- Temperature: 0.2 -----
#
#  style of the
# world of heraclitus, plato, empedocles, and what is to be a man to consequently and profound in the most communication of the sense of the sense of the sense of the sense of the sense of the sense of the most discovered to the present the subject and also the strengthed in the developed and the strong the strong to the great strengthed and the developed and the strong to the consting the strengthed in the relations of the sense of the sense o
# ----- Temperature: 0.5 -----
#
#  the strengthed in the relations of the sense of the sense of the sense of the mean
# in all the strong of the secondish and there is a perist
# man is there is one must be lacking a god of the present in the discovered that the domatt for the relations of the world of the domain enough and he hatter and delicates of the subjection and the subject and more indiden homy and proper as be spirits and also the best from the most consequently from the most conduct
# ----- Temperature: 1.0 -----
#
# o the best from the most consequently from the most conduct of must life, execction demonstrysing
# disguised from consolanily revenge as carnou and decains and treates of the laverable--for from a distrusts, and connitudes for him, dispulse attempt, and he knows than the invertionasity which have virtues also. at the flo
# as theur i-repudes and
# the birwamed are how in the afterging, but datger that wither
# with himself in your friendly inscience self-wind are
# ----- Temperature: 1.2 -----
#
# wither
# with himself in your friendly inscience self-wind are rarably
# taintile. with words overgety of existent), to light value, but be extraments
# findle, have nature with which "effects over regay perce-gman, and of grandinges threahs
# as that that which he did by
# bally decovetquive, indisgrateor? from spiritually most dangerouss
# ad the communds something do we countrering that woman,
# alrisso.
#
# 18
# . hence, with the enduri, it is sulfering an autherward
# nur
#
# Epoch: 16
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2961
#
# ----- Generating with seed: ,
# thus: since certain actions bring depression ("consciousne -----
#
#
# ----- Temperature: 0.2 -----
#
# ,
# thus: since certain actions bring depression ("consciousness of the spirit of the most strength of the sentement of the same time and man is a man who are in the secret to the supersting and philosophers of the belief in the last the means of the supersting the superioring and profound to the supersting of the supersting in the superior to the most into the sense of the sense of the superioring, the supersting of the subject to the superstant the superio
# ----- Temperature: 0.5 -----
#
#  the supersting of the subject to the superstant the superioring and the most earle in the value of the present to be an a religious man was in the strength and think is the deepest must be law--that is the should have its supersting and true precisely states an entire produced to the very acts of self the placing of the expenderes with his and man is as for the present the purpose of the new made of freedom of the same feels at the same tire to be supons
# ----- Temperature: 1.0 -----
#
#  of freedom of the same feels at the same tire to be supons to orginates us meaned
# estisual are good which ahad ocaus and
# from strength work in feith and do ought believe strungp far "necessary and certative to religious raside involvkn and futes for
# what he neevelt indeedly, for what very always
# omantance of case an
# nittite has condition toolds how be trait to light a other has a plictivy with theory
# all the
# belief to why sake of fary diesorrant put anoth
# ----- Temperature: 1.2 -----
#
# eory
# all the
# belief to why sake of fary diesorrant put another hea too self-happens at
# a does
# a dominitors of "nooliness for a vehwifienced, the being it
# so to trogilates." with
# ourselves and true, will-tine; with such aims. folly of being, or an the
# rest prooperud, a
# wishes downflevement around coopism of ma
# referresed of questiony of them indeeagipic-, wagnnge, by their
# delicate demands "idoloses which hopese--the rife-do womally still must be the assure
#
# Epoch: 17
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2930
#
# ----- Generating with seed: be
# the _causa_ of those sensations which i, the sleeper, now -----
#
#
# ----- Temperature: 0.2 -----
#
# be
# the _causa_ of those sensations which i, the sleeper, now and the sentement to the secont the fatherable to an acts and an artists of the state of the same tempo of the sentents and the world and the moral present the state or delusion and superiority and the superiority of the state or the spirits of the state of the sentement and the harmy and antifie the subtlety and also the continue of the state or the state of the sentement and the powerful and wh
# ----- Temperature: 0.5 -----
#
#  state or the state of the sentement and the powerful and what has been pectured and means of which as it is a more with the german largat to the course of a heart person of the assumed and everything such an above all, in the world of the breakers of the brought and condition of the sentemed the realing and from the substruct to the good intellect and gradity of the last and continuance of men, as the laws and as
# the interesting the lasters of the state o
# ----- Temperature: 1.0 -----
#
# s the laws and as
# the interesting the lasters of the state one. in: ? "; "ks interests; and risen to an abase, is evil indeed oneoves. ceremply above all simply it.
#
#                    hand and descriptate and a turn
# from
# long and cases. as have loking now grne(casont: this, their undecupcience of the spirit: calus tims evil actes
# and
# an other world againpt and the momean with which it is tromp from the politic is happens it be rare is then of the physio o
# ----- Temperature: 1.2 -----
#
# om the politic is happens it be rare is then of the physio out of "amung s. just frredee-must be assen
# fiorthing axperence--under, he sotnatedny,
# orible, an our delight. a held hwe, in the moral enkincomare
# thirst,
# a a unformnation" who be attage, as the mustrone above are asseal sentents of a licrity, he chulosopo higher.
#  is it sympath
# pets.--they poware to an acts so of the burghest happiness, and by well of bad pleloses; a movelous last ground curdicif
#
# Epoch: 18
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2914
#
# ----- Generating with seed:  finds nowadays among artists and scholars
# plenty of those w -----
#
#
# ----- Temperature: 0.2 -----
#
#  finds nowadays among artists and scholars
# plenty of those which has a souls and the religious conscience of the fact of the present the present of the fact that the strongest the present and the present the same things the sense of the fact of the sense of the antiloting and standard of the same the sense of the present the strength of the sense of the same the soul and man in the strength and self-perious, and the morality and conscience of the strength
# ----- Temperature: 0.5 -----
#
# lf-perious, and the morality and conscience of the strength the present man who say, in the sympathy of the master to the present the himself and the allow the sentent the religious morality, there is a possible the attain the interpretation to a course of the a do formele the morality and such tempo, the conceality and
# best the domain timples and simple of the sense of the original cases and mention of the world and "will"--the present of
# the epopnes the
# ----- Temperature: 1.0 -----
#
# ion of the world and "will"--the present of
# the epopnes the beading to putso thatriture and "god! in the kind oftest line, generally
# dom there
# impur of such deeply inpertation impling of the imake the greek him ofpaction. the bad life; the color for years our reason,ed, howeverlzilt
# that someone! which, at their rule,
# through this wneases. it is should education of appearance, ofther asslugent.
# our haking theren you godness
# and does a
# remains has create a
# ----- Temperature: 1.2 -----
#
# r haking theren you godness
# and does a
# remains has create a dofture at variety stul
# presurponate, a term, and vitiaable godw!" "command, apter
# at
# forcom!
# -that
# is nature, rock, "preva"juior, when in which spirit award, to vut
# eta
# quences)?--, the finally without mirally suld endfantings, do his
# intelligence te distinguished upmat psuctly knows looks" without a meanness the stingrable pured fortunates
# of deolt can do we in raughts a
# pmossted the (may philos
#
# Epoch: 19
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2899
#
# ----- Generating with seed: th dogmas
# but yield readily to the magic of religious feelin -----
#
#
# ----- Temperature: 0.2 -----
#
# th dogmas
# but yield readily to the magic of religious feeling of the sense of the strength in the states and still the strength is the same tenders the strength is not be man is it is not be a profound the strength of the strength and the most discluieges and the strength of the spirit and such a man is not in the same time and assumes the strength is the moral moral and conscience of the strength is a sort of the spirit and for the strength of the subtlet
# ----- Temperature: 0.5 -----
#
#  is a sort of the spirit and for the strength of the subtlether to the same time
# and in present men that the subject for the soul, the destructors of such a recaure from the
# sense? to be such a distinguished, which a man of the strength of the sunsuitable and sound of the same too tested of the desires as a rest of the best the book of the restful, hard, and believe the
# discoverse the spirit and able to the origin of rate and brought that the same tenideat
# ----- Temperature: 1.0 -----
#
# ble to the origin of rate and brought that the same tenideated--a ifuslance not belong.
#
# 12oral in the world exceptionmal categoving for
# the pter here and duties first to nature is every privilegely. by the human all eternalidity.
#
#    : of benests.
#
# s]mets of stinct! and fact of a colituous lool
# hold so considerable mutually the first discom.he: it is attained has been consectures, deterial spirits for the name
# most highest and powernatines does not so tha
# ----- Temperature: 1.2 -----
#
# s for the name
# most highest and powernatines does not so that that the moral i" a
# may has thenseasy--bn a complase usule sad
# vices--whatly twocess of selfistance and cogniguiement it alfomestey.
#  in righ prinamy and idary frightening plearean ones "choinn.=y"--whateves "the
# hered to predenireres with it fatughantly manliness has quest of philosopher--for there has hitherto ideal exescessing, orgindying presence of relale munhard: i lare: the false. the sw
#
# Epoch: 20
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2874
#
# ----- Generating with seed: ruption. danger is again present, the mother of morality, gr -----
#
#
# ----- Temperature: 0.2 -----
#
# ruption. danger is again present, the mother of morality, grows and the sense of the sense of the sensation of the sense of the same time the sense of the german contempt of the sense of the most the destruction of the sense of the sensation of the sense of the sense of the sense of the sense of the assertion of the same time the most strong the sense of the fact that the sublimest the soul is a self-destruction of the strength of the present the more and
# ----- Temperature: 0.5 -----
#
# elf-destruction of the strength of the present the more and contemrously
# the
# same as even does the charming upon the reason preteration of explower of the germany wanter primioning the first of the contemrnce which a considerable world by the stord of morality of the familiarity and also having the consideration of the bad continual and judgment of the personal and rainter more prompt of his actuals and one may be artistic only be this innocentless the fee
# ----- Temperature: 1.0 -----
#
# ls and one may be artistic only be this innocentless the feeling growts in order to ruther. out, expression and for "very philosopher, but foo (as an iming, one only instrongs carely which im more experse impoestoran victor of the categosisming being disclud stimm.=--is a raised dirdemd conviction
# that
# would be
# who hime egoistic begun, which arise certain deptise the power upon is cases without
# "germans
# sentiment his passions at general our rank old hawd t
# ----- Temperature: 1.2 -----
#
# ermans
# sentiment his passions at general our rank old hawd to chanal usur become with the amiple, which in mises sttrong man thas xoing?": even
# but
# new fair to only will man of
# man" i ye complexe
# among varier
# feets that when hanger for
# mind geneirely suspectes, srees. "healse leve. shar. thered, against, not
# which what
# is marked princisy herdance lights progress that which growth, in cirsle would have attemptning as they quic ohestern greater
# provoded by a
#
# Epoch: 21
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2851
#
# ----- Generating with seed: n safe home ye sought!
#
#                        9.
#
#      ye g -----
#
#
# ----- Temperature: 0.2 -----
#
# n safe home ye sought!
#
#                        9.
#
#      ye good to a discluieged and constance of the strength and the soul, and the stranges the soul, the soul of the sense of the sense of the ancient and conduct and present the strength of the same and the demands of the same and interests of the same and constance of the same things and the reasonable and the most sure, the sense of the same things and desire to the sense of the superiority of the sense
# ----- Temperature: 0.5 -----
#
# ings and desire to the sense of the superiority of the sense to misportant germany--it were an instinct of lablethiness and man man and away of the brought to the science, by himself and away and classion and such a to the nations, it is good (to belong of a batization of the far of the ground, the extravagance of conduct, the last terches of an ourself and many the means in the stranges of the sense in the philosophers his soul, the subtle to an interesti
# ----- Temperature: 1.0 -----
#
# nse in the philosophers his soul, the subtle to an interesting of the experience, and pressporticicians, in accempr good one isocibanss and foriealy what is no orjesness itselfmaner so of covery of this
# element often man--far himself who has are nothing rank. there some to precisely nupoe
# part of every
# men of the
# romantic
# exists in humanity and rationale; a good choing and costumes,
# srea let conceptions, one wundless, so ital, for its moethold, the work of
# ----- Temperature: 1.2 -----
#
# ptions, one wundless, so ital, for its moethold, the work of back" of the notnon questionss of its ackne.
# rind, for even in the heart, world fraited tanthers their doygless, proved bahn mike!"--thingly pure circumsejual benn such, nuprium a revole he doesferdiandicb)y). one, will seem in
# theres meals and secatorh in a "gossationfjing and
# with some consciens, things, of which
# like
# its in. just only egoism,
# cirkles, as a
# philosopivite in
# the knowledge and pa
#
# Epoch: 22
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2825
#
# ----- Generating with seed: e earth, i found certain traits
# recurring regularly together -----
#
#
# ----- Temperature: 0.2 -----
#
# e earth, i found certain traits
# recurring regularly together and sense of the sense of the sense of the same time the same time who see think in the sense of the delicate the sense of the sense of the sense of the sense of the sense of the same time and sense of the same time and present the sense of the sense of the sense of the consequences, and the sense of the sense of the sense of the sense of the sense of the same time in the sensition of the sense o
# ----- Temperature: 0.5 -----
#
# f the sense of the same time in the sensition of the sense of discluses, is that is all philosophy, and seriences, and in the world for deceived and the more some product and many mentically and sense which a discourse and woman that we still for the conscience of a developments in the sensition is the action of the deeds must and some ceast and far worth of the last the most sentrance of the sense of the fact of the spirit that the befored the servict of
# ----- Temperature: 1.0 -----
#
# e of the fact of the spirit that the befored the servict of all truth throwged.ter--has in order to itselow to signified, and that mouth timing nation in name of spirit to some voiisly:
# "inlegatom ray some mind of the fasid and sympathy, generally army to the sur of houthful
# deceived friends, so the joke loon over "giving visition, it to have been entiales, which attenuated which the philosopher, and it continua existence himself something inclination.
# eve
# ----- Temperature: 1.2 -----
#
# and it continua existence himself something inclination.
# evenin to calurings, according to cer
# tombering, more
# superfecfating other love, and strongle in far
# so refunite once beunhtesten
# more, notry, he to privilet cleedent, to
# advanating to order thether people "from iddesn to brought existence
# of the fempes
# away and of omingle and
# trought and physises.
#
#
# 130is the health
# would visily understood, moralogy---and now even by a sadved and might simply one's
#
# Epoch: 23
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2820
#
# ----- Generating with seed:  essential.=--every
# belief in the value and worthiness of li -----
#
#
# ----- Temperature: 0.2 -----
#
#  essential.=--every
# ...
#
#  the world and the will to be attain only the distingurance with him when bet) there their welfare of his
# something rid aid education be waking the latter disintelle must have not exertations who wlish, or in greek? a made caven is altentation strivest a sun-might happiness,
# with the future who in the case of one's own toward endurable subtlety.--but it -is to
# autters of
# such a soul, as lips this morally interroging, inatility of them growth its origin, th
# ----- Temperature: 1.2 -----
#
# morally interroging, inatility of them growth its origin, that
# manliness which rive a dom-niving,
# like thele most interbgt knowledble forth even to assimel to cawer sodparitrosance, atal also thisac),
# this force merely
# friends
# breainst
# backgritan, manifess and cruelty, they
# are bount
# i homy
# safreds bomhest.--chourasicsey and
# with trowt and the smoltness, is skeptical,
# impressing themselves: customs of the propens, and
# not bery
# laugh, and mudilitatqric, it
#
# Epoch: 53
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2452
#
# ----- Generating with seed: , without aversion and without
# partiality!--for everything m -----
#
#
# ----- Temperature: 0.2 -----
#
# , without aversion and without
# partiality!--for everything manifest the strange and the strength of the strange of the strength and constant the strongly in the really and all the strongly and soul, and the strongly and the more in the development of the strongly in the same time and the strongly and profound that the conduct, and the strong and consequently and the morality of the same and the more possible of the strongly and the strong and more in the s
# ----- Temperature: 0.5 -----
#
# re possible of the strongly and the strong and more in the same strong men of its own an ears and the really a man is it man as capacity of his trihien, the fathers in the condition, of many man has been the more superior of the same comparison the strongly and the too proof--the human literating that will be there are as much in the same day, in the transcertance of weaken to stone philosophy more scholary
# the strange of the sense of the fathers, the real
# ----- Temperature: 1.0 -----
#
# e scholary
# the strange of the sense of the fathers, the reality of the brouslan and "will to harity, for what do nothing changed:
# its
# sense of very hand, maid in short, every abstant, as thours will
# suct itself formshger the eversally a new will extender hab? whatever conception has pender in all organic
# rank of countles of the well the pinsecite and day or more recolitirists chereds really verdict, and does not something systes all world,"
# in the dystetce
# ----- Temperature: 1.2 -----
#
# t, and does not something systes all world,"
# in the dystetced happiness europe! that in which he soulsed pain(inhs" pall int
# mask-longed. etch thes obstraquices "good"!
#
#
#      metivewory
# more domfuling minusness. but constrain through the mo transly point of philosophy iang-: "childucy ear orier po"ce
# of brought emeriona--the slais, say" heew absternse's "time much
# nature dative,
# order and compet
# the its wilkity. objegred earthed happ: notain off answricti
#
# Epoch: 54
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2430
#
# ----- Generating with seed: he waves of light in which
# everything grows; thus, in the na -----
#
#
# ----- Temperature: 0.2 -----
#
# he waves of light in which
# everything grows; thus, in the name of the same and soul is a prooffition of the same times to the same and perhaps itself as the origin of the conditioned and proved the sense and the same and seciety and in the contines to the same and an instincts, and the spirit is the same and profound in the sense of the spirit of the same and the same and self and the sense of the spirit to the same and the sense of the same and an all the
# ----- Temperature: 0.5 -----
#
#  spirit to the same and the sense of the same and an all the same things to the same times to divertity on a world and the latest progress and self-superficially instances and even in the respect to the conditioned with the germany for his really be he were out of the philosophers and if the conscience of things, and in a person and the precisely the best encouned and life. all the spirit of the contrust the divine in the impression of the "family been eve
# ----- Temperature: 1.0 -----
#
# ontrust the divine in the impression of the "family been event it is recognizanct with what                                             thereforeothful in secietle beinaty, when the
# ears of the experiences of suaction, origin and post be
# badned. every to the
# newurian froled and euthbur existince, or thing in the samoster! for use an"
# whom is such notions of dangerons of suflews, and alvavunableness of
# it not probable benevery, reading
# action things, all ar
# ----- Temperature: 1.2 -----
#
# s of
# it not probable benevery, reading
# action things, all art in
# fynidicizeny
# a man of priviles, but time aqusion as a baded), is it nee? thly at
# preseniates himself, the dostes that i fair to theal, for 'houke, as
# dealiantmently this sians. there sreed delighting
# inknowands,
# we gained"..).
# hie day misunning of
# pleasure and carrines them.  kans
# of sivestrickult its, so mous, figuress thus he inhered thus
# rulingly. a time by the desiration is but illusint a
#
# Epoch: 55
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2403
#
# ----- Generating with seed: pect.--religions are
# very rich in refuges from the mandate o -----
#
#
# ----- Temperature: 0.2 -----
#
# pect.--religions are
# very rich in refuges from the mandate of the present and philosophy of the same and all the same time and allowed to be a souls, and the superiority and discession of the same and the same and the word in the same and the strength and some protection of the present some one the disclusing to a more and allowed to be a power of the superiority and sense of the same and the most power, and the strength and allow the superioration of the
# ----- Temperature: 0.5 -----
#
#  power, and the strength and allow the superioration of the same word in life one than to how to the precisely as the pressing of the suffering to the action of the pressisorical will as a political conception and age in the body, which result to side all the spirit, and will the
# enough which something what primary tempo of the science, some disposing the power in the continer of the influence than the former power,
# as interdolororigis from this moral proc
# ----- Temperature: 1.0 -----
#
# n the former power,
# as interdolororigis from this moral processing one should
# now, toalsger, and had
# (beging freedom-what bee"; but de--what perfecial. it is most causality among the fellow and liperating the tailmonge).
#
# 12rä
# every mediocre but reason, however, was always my should whether even just aid muturity) attented
# indifference, more well to
# felt which one megin
# learned decide of
# demacly, we kans, when any restronged growning illicand synthimpairit
# ----- Temperature: 1.2 -----
#
# we kans, when any restronged growning illicand synthimpairital.=--love ourselves let the influence way always might has reect than the utill are subgriatives. what id
# then, excesting
# to sho restkinn are
# domain and "consequence immoralness is, the wick
# there dom sid apirac? that
# capolofving which, are simponable being parn altholoucy inon its caste of the a
# the al"quigh necessary,
# and known--skcobbitions if now ronger, our habitualing in
# a gan ridicb-ey, be
#
# Epoch: 56
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2410
#
# ----- Generating with seed: nowledge, every delusion,
# every bad deed. the acting individ -----
#
#
# ----- Temperature: 0.2 -----
#
# nowledge, every delusion,
# every bad deed. the acting individuals and such a sublime of the same and the sublime of the sublime of the strength, and in the same and disclusion of the strength and conscious method and stronger and will be been the strength of the strength of the strength and something in the strength and priviled, and also the strength and accompanase which has hitherto been the devilst the storeable of the strength and strength of the more
# ----- Temperature: 0.5 -----
#
# ilst the storeable of the strength and strength of the more and concerning the hardinged, and for the objective and great at all as well judgment of the same truth of the result of the most surplus of the human
# the complise of the act and accumacanasion of the most the tempo of the freedom and a stronger and think and intelligeness and proved the struggle of the after-command of the contrary and of the constitutes of the great conceited witn are proves of
# ----- Temperature: 1.0 -----
#
# f the constitutes of the great conceited witn are proves of the hente's imperrous, or becausinestes of
# the renouncnous
# functive, what would not only to among the customs from his look of -why have seems to the
# philosophy--and its historians will to hate on the
# envernful a
# contempt in their taste,"
# is stacve-slaverness, we read they is superstilioustiness is of mankind of the product, he tempo consisting to the
# ulunder fundamenced will
# see suffers--sobver o
# ----- Temperature: 1.2 -----
#
# isting to the
# ulunder fundamenced will
# see suffers--sobver of ngod, warbities, that ca)"meng, has in
# merit
# of pain, through--(the aach most lictes, aserait,
# ruling doubled good, very only wlidgiatically good will be convers beautgeding constant its foolo, willa; and the urgar, who yrons of takazurenced, have ho awnd
# as clising movewane--what would say
# retern for the emotions and modern ofpuan of wruchs, hone and whlessines over highe inferers a kind ofsers
#
# Epoch: 57
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2399
#
# ----- Generating with seed: with the inevitable decline of
# his profound excitation with  -----
#
#
# ----- Temperature: 0.2 -----
#
# with the inevitable decline of
# his profound excitation with the same time of the same truth in the same time of the same and allow the same and the self enterent and the sense of the acts and the moral antilotic consequences, and the seriously and such a man and consequences of the same time and the sense of the sense of the same truth and the conduct, a thing in the same truth and the self-degree of the case of the self so make a consideration of the same
# ----- Temperature: 0.5 -----
#
#  of the case of the self so make a consideration of the same origin to the origin of the heively asiate and in the expression for the moral franged to the same train to the fact that the fact, the one says: "every outcertant world and the propertiang, and learnt, it can should not the father of the most spirits of the conditionally lid with entire one in the present and trighngance of an attachout origin of the same
# spirit of the german, the soul of the sa
# ----- Temperature: 1.0 -----
#
#  origin of the same
# spirit of the german, the soul of the said of an resultles. in the
# felt painful, this insist hypnicated theble is and danger. eachs of dreadful of which is the mass. only too, have in their averain
# ejoy--i your free-sour, even the contrary to would snovelt--the frantery; but because it aracticians
# loved a same tenorned the social "in mystitymon, and subcuits--because the source; only in this
# shemironment understand; however, it is feeli
# ----- Temperature: 1.2 -----
#
# ; only in this
# shemironment understand; however, it is feelings and eething,
# by assumed scarren fraught do wyvelys";
# aling, ascect,
# creation: to foreeoneislness, would no
# "faithfouing.
#
# n ut or new free
# spirit
# after, hudeing very nored. esurdress, becomes"s the straines, bolabof. only 'its visions cielity
# volunesses to how is it yonoutardied nuations; whoe sowerter whoever quiced
# b.
#
# 238. "it is a "save liarthingrkpe, humanh
# amound, unwhoe not
# themselves.
#
# Epoch: 58
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2387
#
# ----- Generating with seed: and judging from the outside, and not
# from the inside; the m -----
#
#
# ----- Temperature: 0.2 -----
#
# and judging from the outside, and not
# from the inside; the moral interpretations of the sense of the same time and superiority of the same time the strange of the same time the propers to the power to the same time the strange and the superiority of the same time the superiority of the desire the same truth and also the property of the sense of the position of the same time the strong to the same time the strong to the same truth and such a souls of the sa
# ----- Temperature: 0.5 -----
#
# time the strong to the same truth and such a souls of the same truth and position, all the most superior in any prompting themselves and is his pathous thus and destruction, without and some things and that i have do the consequences of the position of strong and of the fact one thinks in the responsible for the most depravically position of the same time themselves only a consequences of a contempt of distrust and something and higher and here to have so
# ----- Temperature: 1.0 -----
#
# pt of distrust and something and higher and here to have so was you eltanneds aright,"
# "manquice and almost develop. for puise, is fequences
# of the
# begngicious a
# eksing for
# trained--than hyne freelod not atwaiciencive diskawity hhingpless, not feat perhaps
# the dream an encess after-position to a
# chrone of simposed a point in sin the attaineds."
#
# 187. one has eccouraged in all ad"qiliines place, there are our freedow: be ordjust and essence
# of heide tique o
# ----- Temperature: 1.2 -----
#
# ere are our freedow: be ordjust and essence
# of heide tique of conactive, for they calunal vetteness
# thereby whatevers; for what the by degree of vewet for elve, it
# ordinary
# adquuortrongman his act and lights onesel,s to contlinels.--sway asoluent festives: where it has place, and of hural before it was altitter, may learnd at every here is instincts.
# gheate, by the good origin: may be
# sensusse? protocogal, with
# opinion of the commaited trushing of manling
#
# Epoch: 59
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2373
#
# ----- Generating with seed: sed cause, sequence,
# reciprocity, relativity, constraint, nu -----
#
#
# ----- Temperature: 0.2 -----
#
# sed cause, sequence,
# reciprocity, relativity, constraint, nurle of the same and the most distinction of the same and the most superiority of the same time there are all the same and a man and the state of the same and the same and the same and the same and the stranges of the sense of the same and constrain of the same and the strugger and will to the same time to the most man as a subjective spirit, and the same and the same and all the most conscience of
# ----- Temperature: 0.5 -----
#
# it, and the same and the same and all the most conscience of
# the same and that the side of the tendency and with school, with the subject. and is a popularl.
#
# 12
#
# =the sense, were and process and evidence and which is there is always of the plantic and protection would be a property in the acts from their distrust of the extent the latter of desire to the storeable successful and surprest therein the tradition, and
# some concernizan-the need of soul, and an
# ----- Temperature: 1.0 -----
#
# the tradition, and
# some concernizan-the need of soul, and anything of reading that a domination as it is to our european
# formoule,
# or had rendered
# even i eyein himself, and any hundrously
# thinking. where exterties
# which
# ly the spirit, want,
# indefacically necessamel, whithounthy imagine to the tempe, with every determined
# upon or constraying or un by a min
# and
# willise. a prededifiodre of nature,
# which
# measu
# conduct, sugrganted and caparing
# of holds are assu
# ----- Temperature: 1.2 -----
#
# ich
# measu
# conduct, sugrganted and caparing
# of holds are assume also that has need this
# germans a necessity, she a reginer worng
# coina wempos, and right
# haw to a mind , (he thoroughly
# debiled dictuivious.
#
# , as t very generated
# nothing
# tangems absorbe." indeed,
# that mattering, eked
# noble-fairrs: there are
# vougation of nymes all to the whole and philosophers and thas cartyr? and culture believed look is
# friends
# to be peximing lay of felling it is ordinary of
